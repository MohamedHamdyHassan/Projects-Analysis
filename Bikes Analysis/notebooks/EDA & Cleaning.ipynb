# %% [markdown]
# # Bikes Analysis Dataset
# ## Purpose
# > A dataset containing all the required fields to build AI/ML models to find the profit
# ## Description
# > ### --> 10886 records of bikes dataset, containing:
#
#         -   Datetime
#         -   Season
#         -   Holiday
#         -   Workingday
#         -   Weather
#         -   Temp
#         -   Humidity
#         -   Windspeed
#         -   Casual
#         -   Registered
#         -   Rented_bikes_count

# %%
import numpy as np
import pandas as pd

# %%
raw_df=pd.read_csv("../data/raw/bikes.csv")
df=raw_df.copy()

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday weather  temp  humidity  \
# 0  2011-01-01 00:00:00  Spring      0.0         0.0   Clear  9.84      81.0
# 1  2011-01-01 01:00:00  Spring      0.0         0.0     NaN  9.02      80.0
# 2  2011-01-01 02:00:00  Spring      0.0         0.0   Clear  9.02       NaN
# 3  2011-01-01 03:00:00  Spring      0.0         0.0   Clear  9.84      75.0
# 4  2011-01-01 04:00:00     NaN      0.0         0.0   Clear   NaN      75.0
#
#    windspeed  casual  registered  rented_bikes_count
# 0        NaN       3          13                  16
# 1        0.0       8          32                  40
# 2        0.0       5          27                  32
# 3        0.0       3          10                  13
# 4        NaN       0           1                   1

# %% [markdown]
# # EDA (Exploratory Data Analyst)

# %%
df.shape
# Out:
# (10886, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
df.describe().T
# Out:
#                       count        mean         std   min      25%      50%  \
# holiday             10030.0    0.029113    0.168131  0.00   0.0000    0.000
# workingday           9388.0    0.678206    0.467189  0.00   0.0000    1.000
# temp                 8104.0   20.317665    7.818568  0.82  13.9400   20.500
# humidity             7462.0   61.790673   19.262084  0.00  47.0000   62.000
# windspeed            6820.0   12.708806    8.131154  0.00   7.0015   12.998
# casual              10886.0   36.021955   49.960477  0.00   4.0000   17.000
# registered          10886.0  155.552177  151.039033  0.00  36.0000  118.000
# rented_bikes_count  10886.0  191.574132  181.144454  1.00  42.0000  145.000
#
#                          75%       max
# holiday               0.0000    1.0000
# workingday            1.0000    1.0000
# temp                 26.2400   41.0000
# humidity             77.0000  100.0000
# windspeed            16.9979   56.9969
# casual               49.0000  367.0000
# registered          222.0000  886.0000
# rented_bikes_count  284.0000  977.0000

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                 214
# holiday                856
# workingday            1498
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Cleaning of Holiday & Workingday

# %%
def map_holiday(x):
    if str(x['holiday'])=='nan' and str(x['workingday'])!='nan':
        if x['workingday']==0:
            return 1
        else:
            return 0
    else:
        return x['holiday']
    
df['holiday']=df[['holiday','workingday']].apply(map_holiday,axis=1)

# %%
def map_workingday(x):
    if str(x['workingday'])=='nan' and str(x['holiday'])!='nan':
        if x['holiday']==0:
            return 1
        else:
            return 0
    else:
        return x['workingday']
    
df['workingday']=df[['holiday','workingday']].apply(map_workingday,axis=1)

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                 214
# holiday                120
# workingday             120
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# dtype: int64

# %%
df[df.holiday.isnull()==True]
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 17     2011-01-01 17:00:00  Spring      NaN         NaN    Mist  18.04
# 273    2011-01-12 20:00:00     NaN      NaN         NaN   Clear   6.56
# 307    2011-01-14 07:00:00  Spring      NaN         NaN   Clear    NaN
# 308    2011-01-14 08:00:00  Spring      NaN         NaN   Clear   4.92
# 535    2011-02-05 11:00:00  Spring      NaN         NaN   Rainy   9.02
# ...                    ...     ...      ...         ...     ...    ...
# 10404  2012-11-18 22:00:00  Winter      NaN         NaN    Mist  14.76
# 10583  2012-12-07 09:00:00  Winter      NaN         NaN    Mist  12.30
# 10585  2012-12-07 11:00:00  Winter      NaN         NaN    Mist  13.12
# 10782  2012-12-15 16:00:00  Winter      NaN         NaN     NaN  16.40
# 10836  2012-12-17 22:00:00  Winter      NaN         NaN    Mist  17.22
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# 17         82.0    19.0012      15          52                  67
# 273        50.0        NaN       2          54                  56
# 307         NaN    11.0014       0          70                  70
# 308        68.0        NaN       2         156                 158
# 535       100.0     8.9981       1          46                  47
# ...         ...        ...     ...         ...                 ...
# 10404      66.0        NaN       8          66                  74
# 10583      81.0     8.9981      10         291                 301
# 10585       NaN    12.9980      20         183                 203
# 10782       NaN     8.9981      85         328                 413
# 10836       NaN        NaN       5          49                  54
#
# [120 rows x 11 columns]

# %%
df.datetime=pd.to_datetime(df['datetime'])

# %%
df['year']=df.datetime.dt.year
df['month']=df.datetime.dt.month
df['day']=df['datetime'].dt.day_name()

# %%
def day_holiday(x):
    if x['day']=='Saturday' or x['day']=='Sunday':
        return 1 
    else:
        return 0
    
df['holiday']=df[['holiday','day']].apply(day_holiday,axis=1)

# %%
df['workingday']=df[['holiday','workingday']].apply(map_workingday,axis=1)

# %%
df[df.holiday.isnull()==True]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, humidity, windspeed, casual, registered, rented_bikes_count, year, month, day]
# Index: []

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                 214
# holiday                  0
# workingday               0
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# year                     0
# month                    0
# day                      0
# dtype: int64

# %%
def map_season(x):
    if str(x['season'])=='nan':
        if x['month'] in ([12,1,2]):
            return 'Winter'
        elif x['month'] in ([3,4,5]):
            return 'Spring'
        elif x['month'] in ([6,7,8]):
            return 'Summer'
        else:
            return 'Fall'
    else:
        return x['season']
    
df['season']=df.apply(map_season,axis=1)

# %%
df[['season','holiday','workingday','month','day']]
# Out:
#        season  holiday  workingday  month        day
# 0      Spring        1         0.0      1   Saturday
# 1      Spring        1         0.0      1   Saturday
# 2      Spring        1         0.0      1   Saturday
# 3      Spring        1         0.0      1   Saturday
# 4      Winter        1         0.0      1   Saturday
# ...       ...      ...         ...    ...        ...
# 10881  Winter        0         1.0     12  Wednesday
# 10882  Winter        0         1.0     12  Wednesday
# 10883  Winter        0         1.0     12  Wednesday
# 10884  Winter        0         1.0     12  Wednesday
# 10885  Winter        0         1.0     12  Wednesday
#
# [10886 rows x 5 columns]

# %%
def season(x):
    if x['month'] in ([12,1,2]):
        return 'Winter'
    elif x['month'] in ([3,4,5]):
        return 'Spring'
    elif x['month'] in ([6,7,8]):
        return 'Summer'
    else:
        return 'Fall'
    
df['season']=df.apply(season,axis=1)

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                   0
# holiday                  0
# workingday               0
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# year                     0
# month                    0
# day                      0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# datetime              0
# season                0
# holiday               0
# workingday            0
# weather               0
# temp                  0
# humidity              0
# windspeed             0
# casual                0
# registered            0
# rented_bikes_count    0
# year                  0
# month                 0
# day                   0
# dtype: int64

# %%
df.to_csv('../data/processed/EDA & Cleaning.csv')
